# %%
import pandas as pd

# %%
# !ls norms
# Out:
# norms1.tab norms2.tab norms3.tab norms4.tab

# %%
df = pd.read_csv('norms/norms1.tab', sep='\t', lineterminator='\n')
df.shape
# Out:
# (6187, 5)

# %%
df.T.head()
# Out:
#                       0               1               2               3     \
# user_id              56118           56118           56118           56118
# file_id          N01005HL9       N01005HL9       N01005HL9       N01005HL9
# segment_id  N01005HL9_0001  N01005HL9_0002  N01005HL9_0003  N01005HL9_0004
# norm                  none             102            none            none
# status            EMPTY_NA          adhere        EMPTY_NA        EMPTY_NA
#
#                       4               5               6               7     \
# user_id              56118           56118           56118           56118
# file_id          N01005HL9       N01005HL9       N01005HL9       N01005HL9
# segment_id  N01005HL9_0005  N01005HL9_0006  N01005HL9_0007  N01005HL9_0008
# norm                   108            none            none            none
# status              adhere        EMPTY_NA        EMPTY_NA        EMPTY_NA
#
# ...

# %%
print(df['file_id'].nunique())
df['file_id'].unique()
# Out:
# 307
# array(['N01005HL9', 'N01005HM1', 'N01005HM7', 'N01005HU1', 'N01005HXO',
#        'N01005HYC', 'N01005HZ5', 'N01005I2A', 'N01005I7P', 'N01005I8P',
#        'N01005IA8', 'N01005IAW', 'N01005ICW', 'N01005IEB', 'N01005IED',
#        'N01005II9', 'N01005IOM', 'N01005IWU', 'N01005J98', 'N01005J9N',
#        'N01005JCD', 'N01005JE0', 'N01005JG4', 'N01005JL4', 'N01005JM1',
#        'N01005JP2', 'N01005JW2', 'N01005KD8', 'N01005KF4', 'N01005KG5',
#        'N01005KMH', 'N01005KMJ', 'N01005L4U', 'N01005LBM', 'N01005LPW',
#        'N01005LQ0', 'N01005LQO', 'N01005LR1', 'N01005LVW', 'N01005LYE',
#        'N01005LYI', 'N01005LYR', 'N01005M02', 'N01005M0Y', 'N01005M19',
#        'N010069MX', 'N010069W0', 'N01006AO4', 'N01006APQ', 'N01006AT2',
#        'N01006ATK', 'N01006AUR', 'N01006AVB', 'N01006BCI', 'N01006BMV',
#        'N01006BQB', 'N01006BQS', 'N01006BS7', 'N01006BTP', 'N01006BW7',
#        'N01006BZO', 'N01006C1D', 'N01006C9B', 'N01006CAX', 'N01006CBH',
# ...

# %%
df2 = pd.read_csv('norms/norms2.tab', sep='\t', lineterminator='\n')
df2.shape
# Out:
# (19968, 5)

# %%
print(df2['file_id'].nunique())
df2['file_id'].unique()
# Out:
# 608
# array(['N01005FR3', 'N01005FRH', 'N01005FRW', 'N01005FSF', 'N01005FTX',
#        'N01005FVR', 'N01005FXS', 'N01005FYL', 'N01005G0X', 'N01005G11',
#        'N01005G19', 'N01005G1S', 'N01005G25', 'N01005G3S', 'N01005G5C',
#        'N01005G87', 'N01005G8M', 'N01005G92', 'N01005G9H', 'N01005GBY',
#        'N01005GCI', 'N01005GCQ', 'N01005GCW', 'N01005GD3', 'N01005GF9',
#        'N01005GHE', 'N01005GHT', 'N01005GIH', 'N01005GKC', 'N01005GKD',
#        'N01005GKS', 'N01005GLO', 'N01005GM2', 'N01005GRX', 'N01005GXI',
#        'N01005H1X', 'N01005H41', 'N01005H7D', 'N01005HAV', 'N01005HAZ',
#        'N01005HBC', 'N01005HBH', 'N01005HC0', 'N01005HCX', 'N01005HDG',
#        'N01005HED', 'N01005HGG', 'N01005HL9', 'N01005HM1', 'N01005HM7',
#        'N01005HNK', 'N01005HOG', 'N01005HU1', 'N01005HXO', 'N01005HXS',
#        'N01005HYC', 'N01005HZ5', 'N01005I2A', 'N01005I7J', 'N01005I7P',
#        'N01005I8P', 'N01005IA8', 'N01005IAW', 'N01005ICW', 'N01005IEB',
# ...

# %%
df3 = pd.read_csv('norms/norms3.tab', sep='\t', lineterminator='\n')
df3.shape
# Out:
# (32632, 5)

# %%
print(df3['file_id'].nunique())
df3['file_id'].unique()
# Out:
# 622
# array(['N01005FR3', 'N01005FRH', 'N01005FRW', 'N01005FSF', 'N01005FTX',
#        'N01005FVR', 'N01005FX0', 'N01005FXD', 'N01005FXS', 'N01005FYL',
#        'N01005G0X', 'N01005G11', 'N01005G19', 'N01005G1S', 'N01005G25',
#        'N01005G3S', 'N01005G5C', 'N01005G87', 'N01005G8M', 'N01005G92',
#        'N01005G9H', 'N01005GBY', 'N01005GCI', 'N01005GCQ', 'N01005GCW',
#        'N01005GD3', 'N01005GF9', 'N01005GHE', 'N01005GHT', 'N01005GIH',
#        'N01005GKC', 'N01005GKD', 'N01005GKS', 'N01005GLO', 'N01005GM2',
#        'N01005GRX', 'N01005GXI', 'N01005H1X', 'N01005H41', 'N01005H7D',
#        'N01005HAV', 'N01005HAZ', 'N01005HBC', 'N01005HBH', 'N01005HC0',
#        'N01005HCX', 'N01005HDG', 'N01005HED', 'N01005HGG', 'N01005HL9',
#        'N01005HM1', 'N01005HM7', 'N01005HNK', 'N01005HOG', 'N01005HU1',
#        'N01005HXO', 'N01005HXS', 'N01005HYC', 'N01005HZ5', 'N01005I2A',
#        'N01005I7J', 'N01005I7P', 'N01005I8P', 'N01005IA8', 'N01005IAW',
# ...

# %%
df4 = pd.read_csv('norms/norms4.tab', sep='\t', lineterminator='\n')
df4.shape
# Out:
# (34322, 5)

# %%
print(df4['file_id'].nunique())
df4['file_id'].unique()
# Out:
# 617
# array(['N01005FR3', 'N01005FRH', 'N01005FRW', 'N01005FSF', 'N01005FTX',
#        'N01005FVR', 'N01005FX0', 'N01005FXD', 'N01005FXS', 'N01005FYL',
#        'N01005G0X', 'N01005G11', 'N01005G19', 'N01005G1S', 'N01005G25',
#        'N01005G3S', 'N01005G5C', 'N01005G87', 'N01005G8M', 'N01005G92',
#        'N01005G9H', 'N01005GBY', 'N01005GCI', 'N01005GCQ', 'N01005GCW',
#        'N01005GD3', 'N01005GF9', 'N01005GHE', 'N01005GHT', 'N01005GIH',
#        'N01005GKC', 'N01005GKD', 'N01005GKS', 'N01005GLO', 'N01005GM2',
#        'N01005GRX', 'N01005GXI', 'N01005H1X', 'N01005H41', 'N01005H7D',
#        'N01005HAV', 'N01005HAZ', 'N01005HBC', 'N01005HBH', 'N01005HC0',
#        'N01005HCX', 'N01005HDG', 'N01005HED', 'N01005HGG', 'N01005HL9',
#        'N01005HM1', 'N01005HM7', 'N01005HNK', 'N01005HOG', 'N01005HU1',
#        'N01005HXO', 'N01005HXS', 'N01005HYC', 'N01005HZ5', 'N01005I2A',
#        'N01005I7J', 'N01005I7P', 'N01005I8P', 'N01005IA8', 'N01005IAW',
# ...

# %%
all_df = pd.concat([df,df2,df3,df4])
all_df.shape
# Out:
# (93109, 5)

# %%
print(all_df['file_id'].nunique())
all_df['file_id'].unique()
# Out:
# 623
# array(['N01005HL9', 'N01005HM1', 'N01005HM7', 'N01005HU1', 'N01005HXO',
#        'N01005HYC', 'N01005HZ5', 'N01005I2A', 'N01005I7P', 'N01005I8P',
#        'N01005IA8', 'N01005IAW', 'N01005ICW', 'N01005IEB', 'N01005IED',
#        'N01005II9', 'N01005IOM', 'N01005IWU', 'N01005J98', 'N01005J9N',
#        'N01005JCD', 'N01005JE0', 'N01005JG4', 'N01005JL4', 'N01005JM1',
#        'N01005JP2', 'N01005JW2', 'N01005KD8', 'N01005KF4', 'N01005KG5',
#        'N01005KMH', 'N01005KMJ', 'N01005L4U', 'N01005LBM', 'N01005LPW',
#        'N01005LQ0', 'N01005LQO', 'N01005LR1', 'N01005LVW', 'N01005LYE',
#        'N01005LYI', 'N01005LYR', 'N01005M02', 'N01005M0Y', 'N01005M19',
#        'N010069MX', 'N010069W0', 'N01006AO4', 'N01006APQ', 'N01006AT2',
#        'N01006ATK', 'N01006AUR', 'N01006AVB', 'N01006BCI', 'N01006BMV',
#        'N01006BQB', 'N01006BQS', 'N01006BS7', 'N01006BTP', 'N01006BW7',
#        'N01006BZO', 'N01006C1D', 'N01006C9B', 'N01006CAX', 'N01006CBH',
# ...

# %%
with open('file_ids.txt','w') as content_file:
    for f in all_df['file_id'].unique():
        content_file.write(f)
        content_file.write('\n')
content_file.close()
